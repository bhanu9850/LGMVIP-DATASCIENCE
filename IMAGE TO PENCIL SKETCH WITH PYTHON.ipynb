# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %%
image=cv2.imread("elephant.jfif")
image = cv2.resize(image,(500,300))
image
# Out:
# array([[[210, 235, 239],
#         [209, 234, 238],
#         [208, 233, 237],
#         ...,
#         [102, 104, 114],
#         [ 83,  87,  96],
#         [ 72,  77,  86]],
#
#        [[207, 235, 235],
#         [207, 234, 235],
#         [206, 234, 235],
#         ...,
#         [112, 116, 125],
#         [ 88,  93, 102],
#         [ 74,  80,  89]],
#
#        [[202, 234, 230],
#         [202, 234, 231],
#         [203, 235, 231],
#         ...,
#         [127, 132, 141],
#         [ 97, 103, 112],
#         [ 79,  86,  96]],
#
#        ...,
#
#        [[181, 217, 193],
#         [171, 209, 184],
#         [155, 194, 168],
#         ...,
#         [134, 184, 154],
#         [144, 193, 164],
#         [149, 198, 170]],
#
#        [[199, 233, 212],
#         [188, 222, 201],
#         [168, 205, 182],
#         ...,
#         [133, 184, 155],
#         [143, 193, 165],
#         [148, 198, 170]],
#
#        [[211, 243, 226],
#         [199, 232, 214],
#         [178, 213, 192],
#         ...,
#         [132, 183, 156],
#         [142, 193, 165],
#         [147, 198, 171]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[233, 232, 231, ..., 107,  89,  79],
#        [232, 231, 231, ..., 118,  95,  82],
#        [229, 229, 230, ..., 134, 105,  88],
#        ...,
#        [206, 197, 182, ..., 169, 179, 184],
#        [223, 212, 194, ..., 170, 179, 184],
#        [234, 223, 203, ..., 169, 179, 184]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[ 22,  23,  24, ..., 148, 166, 176],
#        [ 23,  24,  24, ..., 137, 160, 173],
#        [ 26,  26,  25, ..., 121, 150, 167],
#        ...,
#        [ 49,  58,  73, ...,  86,  76,  71],
#        [ 32,  43,  61, ...,  85,  76,  71],
#        [ 21,  32,  52, ...,  86,  76,  71]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[ 29,  29,  28, ..., 124, 123, 123],
#        [ 29,  29,  29, ..., 123, 122, 122],
#        [ 31,  31,  31, ..., 118, 117, 117],
#        ...,
#        [ 68,  68,  68, ...,  82,  83,  83],
#        [ 67,  67,  67, ...,  82,  83,  83],
#        [ 67,  67,  67, ...,  83,  83,  83]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>
# <PIL.Image.Image image mode=L size=500x300>

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
